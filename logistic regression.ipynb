# %%
# "C:\Users\2025\Desktop\Intellipat_learning\bank-additional-full.csv"

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\2025\Desktop\Intellipat_learning\bank-additional-full.csv",sep=';')

# %%
data
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
data['y'].value_counts()
# Out:
# y
# no     36556
# yes     4640
# Name: count, dtype: int64

# %%
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
data.shape
# Out:
# (41199, 21)

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
data['job'].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1726
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
## replace thee values in 1 as yes and 0 as no

data['y'] = np.where(data['y'] == 'yes',1,0)
data['y'] = data['y'].astype(str)

# %%
data.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data['y'].value_counts()
# Out:
# y
# 0    36559
# 1     4640
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
data.describe(include='all')
# Out:
#                  age     job  marital          education default housing  \
# count   41195.000000   41194    41194              41194   41195   41196
# unique           NaN      12        4                  8       3       3
# top              NaN  admin.  married  university.degree      no     yes
# freq             NaN   10422    24934              12168   32595   21584
# mean       40.030319     NaN      NaN                NaN     NaN     NaN
# std        10.431818     NaN      NaN                NaN     NaN     NaN
# min        17.000000     NaN      NaN                NaN     NaN     NaN
# 25%        32.000000     NaN      NaN                NaN     NaN     NaN
# 50%        38.000000     NaN      NaN                NaN     NaN     NaN
# 75%        47.000000     NaN      NaN                NaN     NaN     NaN
# max        98.000000     NaN      NaN                NaN     NaN     NaN
#
#          loan   contact  month day_of_week  ...      campaign         pdays  \
# ...

# %%
data['marital'].value_counts()
# Out:
# marital
# married     24934
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
data['job'].mode() # An example to calculate the mode of a column
# Out:
# 0    admin.
# Name: job, dtype: object

# %%
import statistics as st

# %%
data.duplicated().sum()
# Out:
# np.int64(15)

# %%
import seaborn as sns
sns.boxplot(x=data['age'])
# Out:
# <Axes: xlabel='age'>

# %%
col_list = list(data.columns)
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
import matplotlib.pyplot as plt

# %%
for i in col_list:
    if(data[i].dtype!='object'):
        plt.figure()
        sns.boxplot(x=data[i])

# %%
for i in col_list:
    if(data[i].dtypes == 'float64'):
        q1 = data[i].quantile(0.25)
        q3 = data[i].quantile(0.75)
        IQR = q3 - q1
        data1 = data[(data[i] >= (q1 - 1.5*IQR)) & (data[i] <= (q1 + 1.5*IQR))]

# %%
data1
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41193  94.0    retired  married  professional.course       no     yes   no
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
for i in col_list:
    if(data[i].dtype!='object'):
        plt.figure()
        sns.boxplot(x=data1[i])

# %%
numeric_data = data.select_dtypes(include=['number'])

Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)
IQR = Q3 - Q1

print(IQR)
# Out:
# age                15.000
# duration          217.000
# campaign            2.000
# pdays               0.000
# previous            0.000
# emp.var.rate        3.200
# cons.price.idx      0.919
# cons.conf.idx       6.300
# euribor3m           3.617
# nr.employed       129.000
# dtype: float64

# %%
numeric_data = data.select_dtypes(include=['number'])

Q1 = numeric_data.quantile(0.25)
Q3 = numeric_data.quantile(0.75)
IQR = Q3 - Q1

mask = ~((numeric_data < (Q1 - 1.5 * IQR)) | 
         (numeric_data > (Q3 + 1.5 * IQR))).any(axis=1)

data = data[mask]

# %%
data
# Out:
#         age         job  marital            education  default housing loan  \
# 0      56.0   housemaid  married             basic.4y       no      no   no
# 1      57.0    services  married          high.school  unknown      no   no
# 2      37.0    services  married          high.school       no     yes   no
# 3      40.0      admin.  married             basic.6y       no      no   no
# 4      56.0    services  married          high.school       no      no  yes
# ...     ...         ...      ...                  ...      ...     ...  ...
# 41185  56.0     retired  married    university.degree       no     yes   no
# 41186  44.0  technician  married  professional.course       no      no   no
# 41188   NaN         NaN      NaN                  NaN      NaN     NaN  NaN
# 41191   NaN         NaN      NaN                  NaN      NaN     NaN  NaN
# 41197   NaN         NaN      NaN                  NaN      NaN     NaN  NaN
#
# ...

# %%
data.shape
# Out:
# (30363, 21)

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#         age          job  marital            education  default housing loan  \
# 0      56.0    housemaid  married             basic.4y       no      no   no
# 1      57.0     services  married          high.school  unknown      no   no
# 2      37.0     services  married          high.school       no     yes   no
# 3      40.0       admin.  married             basic.6y       no      no   no
# 4      56.0     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 41181  37.0       admin.  married    university.degree       no     yes   no
# 41184  46.0  blue-collar  married  professional.course       no      no   no
# 41185  56.0      retired  married    university.degree       no     yes   no
# 41186  44.0   technician  married  professional.course       no      no   no
# 41188   NaN          NaN      NaN                  NaN      NaN     NaN  NaN
#
# ...

# %%
col_list.remove('y')

# %%
for i in col_list:
    if data[i].dtypes == 'object':
        data[i] = data[i].fillna(data[i].mode()[0])
    else:
        data[i] = data[i].fillna(data[i].mean())

# %%
data.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data['age'].unique()
# Out:
# array([56.        , 57.        , 37.        , 40.        , 45.        ,
#        59.        , 41.        , 24.        , 25.        , 29.        ,
#        35.        , 54.        , 46.        , 50.        , 39.        ,
#        30.        , 55.        , 49.        , 34.        , 58.        ,
#        32.        , 38.        , 44.        , 42.        , 60.        ,
#        53.        , 47.        , 48.        , 33.        , 51.        ,
#        31.        , 52.        , 43.        , 36.        , 28.        ,
#        27.        , 26.        , 22.        , 23.        , 20.        ,
#        21.        , 61.        , 19.        , 18.        , 66.        ,
#        68.        , 63.        , 62.        , 65.        , 64.        ,
#        67.        , 69.        , 39.67162015])

# %%
data['age'].min(),data['age'].max()
# Out:
# (18.0, 69.0)

# %%
bins = [10,25,50,100]

# %%
data['age'] = pd.cut(data['age'],bins)
data['age'] = data.age.astype(str)

# %%
data
# Out:
#              age          job  marital            education  default housing  \
# 0      (50, 100]    housemaid  married             basic.4y       no      no
# 1      (50, 100]     services  married          high.school  unknown      no
# 2       (25, 50]     services  married          high.school       no     yes
# 3       (25, 50]       admin.  married             basic.6y       no      no
# 4      (50, 100]     services  married          high.school       no      no
# ...          ...          ...      ...                  ...      ...     ...
# 41181   (25, 50]       admin.  married    university.degree       no     yes
# 41184   (25, 50]  blue-collar  married  professional.course       no      no
# 41185  (50, 100]      retired  married    university.degree       no     yes
# 41186   (25, 50]   technician  married  professional.course       no      no
# 41188   (25, 50]       admin.  married    university.degree       no     yes
#
# ...

# %%
col_list = []

for col in data.columns:
    if((data[col].dtype == 'object') & (col != 'y')):
        col_list.append(col)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in col_list:
    data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181    1    0        1          6        0        2     0        0      7
# 41184    1    1        1          5        0        0     0        0      7
# 41185    2    5        1          6        0        2     0        0      7
# 41186    1    9        1          5        0        0     0        0      7
# 41188    1    0        1          6        0        2     0        0      6
#
# ...

# %%
## checking for multicolinarity
from statsmodels.stats.outliers_influence import variance_inflation_factor

col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
X = data[col_list]
X
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181    1    0        1          6        0        2     0        0      7
# 41184    1    1        1          5        0        0     0        0      7
# 41185    2    5        1          6        0        2     0        0      7
# 41186    1    9        1          5        0        0     0        0      7
# 41188    1    0        1          6        0        2     0        0      6
#
# ...

# %%
X.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
## for calculationg VIF we only need to pass the values present in the data

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

# %%
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature            VIF
# 0              age       1.099717
# 1              job       1.025347
# 2          marital       1.095754
# 3        education       1.099320
# 4          default       1.091918
# 5          housing       1.013140
# 6             loan       1.003020
# 7          contact       2.719010
# 8            month       2.059329
# 9      day_of_week       1.010863
# 10        duration       1.011890
# 11        campaign       1.019597
# 12           pdays  771198.558198
# 13        previous            NaN
# 14        poutcome            NaN
# 15    emp.var.rate      41.956355
# 16  cons.price.idx       8.722060
# 17   cons.conf.idx       3.875263
# 18       euribor3m      88.823988
# 19     nr.employed      35.200577

# %%
data = data.drop(['pdays'],axis=1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature           VIF
# 0              age      8.703541
# 1              job      2.094922
# 2          marital      5.200237
# 3        education      4.459799
# 4          default      1.410680
# 5          housing      2.192937
# 6             loan      1.208348
# 7          contact      3.589692
# 8            month      7.817687
# 9      day_of_week      3.105862
# 10        duration      3.172537
# 11        campaign      3.621027
# 12        previous           NaN
# 13        poutcome           NaN
# 14    emp.var.rate     41.967512
# 15  cons.price.idx  51250.717668
# 16   cons.conf.idx    160.362837
# 17       euribor3m    439.057859
# 18     nr.employed  58401.342876

# %%
data = data.drop(['nr.employed'],axis=1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature         VIF
# 0              age    8.703481
# 1              job    2.094880
# 2          marital    5.199552
# 3        education    4.459796
# 4          default    1.409517
# 5          housing    2.192319
# 6             loan    1.208247
# 7          contact    2.750130
# 8            month    6.752799
# 9      day_of_week    3.105238
# 10        duration    3.163186
# 11        campaign    3.609366
# 12        previous         NaN
# 13        poutcome         NaN
# 14    emp.var.rate   28.396222
# 15  cons.price.idx  416.186545
# 16   cons.conf.idx  141.730555
# 17       euribor3m  203.181666

# %%
data = data.drop(['cons.price.idx'],axis=1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age   8.405210
# 1             job   2.085971
# 2         marital   5.077216
# 3       education   4.387125
# 4         default   1.406893
# 5         housing   2.187490
# 6            loan   1.207616
# 7         contact   2.505481
# 8           month   6.416071
# 9     day_of_week   3.082334
# 10       duration   3.124316
# 11       campaign   3.573087
# 12       previous        NaN
# 13       poutcome        NaN
# 14   emp.var.rate  14.554363
# 15  cons.conf.idx  46.936086
# 16      euribor3m  83.511636

# %%
data = data.drop(['euribor3m'],axis=1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age   7.810639
# 1             job   2.075216
# 2         marital   4.972897
# 3       education   4.198549
# 4         default   1.406724
# 5         housing   2.176948
# 6            loan   1.207349
# 7         contact   2.495769
# 8           month   5.783523
# 9     day_of_week   3.034212
# 10       duration   3.098699
# 11       campaign   3.565451
# 12       previous        NaN
# 13       poutcome        NaN
# 14   emp.var.rate   1.409676
# 15  cons.conf.idx  23.712348

# %%
data = data.drop(['cons.conf.idx'],axis=1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature       VIF
# 0            age  5.885475
# 1            job  2.048652
# 2        marital  4.109709
# 3      education  3.947330
# 4        default  1.396168
# 5        housing  2.109334
# 6           loan  1.202310
# 7        contact  2.483146
# 8          month  5.136407
# 9    day_of_week  2.893521
# 10      duration  2.925077
# 11      campaign  3.253768
# 12      previous       NaN
# 13      poutcome       NaN
# 14  emp.var.rate  1.405974

# %%
data = data.drop(['previous','poutcome'],axis = 1)

# %%
col_list = []

for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y')):
        col_list.append(col)
X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"]= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature       VIF
# 0            age  5.885475
# 1            job  2.048652
# 2        marital  4.109709
# 3      education  3.947330
# 4        default  1.396168
# 5        housing  2.109334
# 6           loan  1.202310
# 7        contact  2.483146
# 8          month  5.136407
# 9    day_of_week  2.893521
# 10      duration  2.925077
# 11      campaign  3.253768
# 12  emp.var.rate  1.405974

# %%
vif_data.feature
# Out:
# 0              age
# 1              job
# 2          marital
# 3        education
# 4          default
# 5          housing
# 6             loan
# 7          contact
# 8            month
# 9      day_of_week
# 10        duration
# 11        campaign
# 12    emp.var.rate
# Name: feature, dtype: object

# %%
Ind_Features = list(vif_data.feature)
Ind_Features
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'emp.var.rate']

# %%
df_ind = data[Ind_Features]
df_ind
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        2    3        1          0        0        0     0        1      6
# 1        2    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        2    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181    1    0        1          6        0        2     0        0      7
# 41184    1    1        1          5        0        0     0        0      7
# 41185    2    5        1          6        0        2     0        0      7
# 41186    1    9        1          5        0        0     0        0      7
# 41188    1    0        1          6        0        2     0        0      6
#
#        day_of_week    duration  campaign  emp.var.rate
# ...

# %%
df_dep = data['y']
df_dep
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41181    1
# 41184    0
# 41185    0
# 41186    1
# 41188    0
# Name: y, Length: 30350, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_ind,df_dep,test_size=0.25,random_state = 100)

# %%
x_train.head()
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 7973     1    3        1          1        0        2     0        1      4
# 966      1    0        1          6        0        2     0        1      6
# 10340    1    4        0          2        1        2     0        1      4
# 18519    2    9        0          6        1        2     0        0      3
# 28104    1    2        1          3        0        0     0        0      0
#
#        day_of_week  duration  campaign  emp.var.rate
# 7973             1      45.0       3.0           1.4
# 966              4      37.0       2.0           1.1
# 10340            1      73.0       2.0           1.4
# 18519            2      49.0       1.0           1.4
# 28104            0     224.0       2.0          -1.8

# %%
x_train.shape
# Out:
# (22762, 13)

# %%
x_test.shape
# Out:
# (7588, 13)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logesticRegr = LogisticRegression()

# %%
logesticRegr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
test_pred = logesticRegr.predict(x_test)

# %%
test_pred
# Out:
# array(['0', '0', '0', ..., '0', '0', '0'], shape=(7588,), dtype=object)

# %%
pd.DataFrame(logesticRegr.predict_proba(x_test))
# Out:
#              0         1
# 0     0.947996  0.052004
# 1     0.937938  0.062062
# 2     0.994674  0.005326
# 3     0.998199  0.001801
# 4     0.997764  0.002236
# ...        ...       ...
# 7583  0.994403  0.005597
# 7584  0.992063  0.007937
# 7585  0.989920  0.010080
# 7586  0.996739  0.003261
# 7587  0.991616  0.008384
#
# [7588 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
c1 = confusion_matrix(y_test,test_pred)

# %%
c1
# Out:
# array([[7098,   97],
#        [ 339,   54]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7195
#            1       0.36      0.14      0.20       393
#
#     accuracy                           0.94      7588
#    macro avg       0.66      0.56      0.58      7588
# weighted avg       0.92      0.94      0.93      7588

# %%
accuracy_score(y_test,test_pred)
# Out:
# 0.9425408539799683
